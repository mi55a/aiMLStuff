# %%
!

# %% [markdown]
# Hello! Welcome to Python (Taylor's Version) (From the Machine Learning Vault) (Sad Girl Autumnn Version)
#
# Ny name is Mily and I'm the author of this notebook. I started this notebook as a project for myself, but also a handbook for other Python enthusiasts. I thought to myself, "What are two topics that I love?": Taylor Swift and machine learning.

# %%
print("Hello fellow Swiftie or just an interested user!")
# Out:
# Hello fellow Swiftie or just an interested user!
