# %% [markdown]
# <center><img src="/Users/milymendez/aiMLStuff/midnightspy.png" width=500 height=500/></center>

# %% [markdown]
# <h1>Meet Me at Midnight</h1>

# %% [markdown]
# Hello! Welcome to Python (Taylor's Version) (From the Machine Learning Vault) (Sad Girl Autumn Version)
#
# My name is Mily and I'm the author of this notebook. I started this notebook as a project for myself, but also a handbook for other Python enthusiasts. I thought to myself, "What are two topics that I love?": Taylor Swift and machine learning.
#
# Yeah... those topics don't really correleate but they do in my heart <3
#
# Here, I am documenting the process of some of my machine learning programs with my favorite data set of all time: taylor_swift_spotify_data.csv!
#
# I will also talk about machine learning methods, libraries, Python concepts, and how you can create your own program!
#
# You might be asking yourself, "What is machine learning? What is Python? When will Taylor drop reputation TV? (Maybe she has already dropped it at the time of you reading this)
#
# One is probably already familiar with artificial intelligence and if you aren't, that's totally fine! Artificial intelligence is defined as the theory and development of computer systems able to perform tasks normally requiring human intelligence. To put it in Swiftie terms, it's the technology that is used to make all those Taylor Swift AI song or album covers. It's the technology that is taking the world by storm.
#
# AI is just the tip of the iceberg. Now, for the star of the show: machine learning!
#
# Machine learning is a subfield of artificial intelligence, defined as giving computers the ability to learn without being explicitly programmed. Basically, machine learning learns (haha learning, do you get it?) from artifical intelligence. Examples of machine learning are speech recognition, recommendation systems, and image classification! Pretty cool, isn't it?
#
# Now that you're a bit familiar with AI and machine learning, let's deep dive into the fields' favorite language: Python! Python is a high-level programming language that priotitizes code efficiency and is object-oriented. Basically, it's very readable to the human eye and it's quite simple!
#
# Python is to machine learning and AI what Red TV is to Taylor Swift. Let's start with some basic commands!

# %% [markdown]
# <h3>Comments</h3>

# %%
# This is how you make a comement! Comments are important when writing programs, specially when you need to explain how a complicated functions works or what it does
# Write something here and make your own comment as well. 
#

# %% [markdown]
# <h3>Print Command</h3>

# %% [markdown]
# Probably one of the most important commands in the language since it's the one that allows you to print out your output, be it anything! The nice thing about Jupyter notebooks (what we're using right now) doesn't require the print() command to print out variables (for later!) but keep it in mind for other IDEs!

# %%
# Print command
print("This is a statement that is being printed out")
# Out:
# This is a statement that is being printed out

# %% [markdown]
# <h3>Variables</h3>

# %% [markdown]
# Variables hold pieces of memory and something, an integer, text, decimal, or T/F.

# %%
integer = 4
string = "Your name!"
doubleOrdecimal = 4.4
trueOrfalse = True
